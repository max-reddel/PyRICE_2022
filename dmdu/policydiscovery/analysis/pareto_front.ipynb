# %% [markdown]
# # Pareto Fronts
#
# For UD and SD

# %%
from model.enumerations import ProblemFormulation
import os
import pandas as pd

directory = os.path.join(
    os.path.dirname(os.getcwd()),
    'paretosorting',
    'data',
    'final',
)

outcome_names = [
    'Utility 2105',
    'Disutility 2105',
    'Temperature overshoot 2105'
]

# %% [markdown]
# ## Load Policies and their objectives

# %%
pf = ProblemFormulation.UTILITARIAN_DISAGGREGATED
df_UD = pd.read_csv(os.path.join(directory, f'sorted_{pf.name}.csv'))
df_UD
# Out:
#     Unnamed: 0.1  Unnamed: 0        sr          miu  irstp_consumption  \
# 0              0          72  0.128922  2065.000000              0.001
# 1              1         293  0.203102  2065.000000              0.001
# 2              2         502  0.164027  2065.000000              0.001
# 3              0         166  0.170948  2065.000001              0.001
# 4              1         330  0.210783  2065.000000              0.001
# 5              2         728  0.134011  2065.000000              0.001
# 6              0         210  0.169294  2065.000000              0.001
# 7              1         224  0.242804  2065.000000              0.001
# 8              2         259  0.104831  2065.000000              0.001
# 9              3         838  0.204934  2065.000000              0.001
# 10             0         719  0.220628  2065.000005              0.001
# 11             1        1330  0.246556  2065.000000              0.001
# 12             2        1597  0.101473  2065.000000              0.001
# 13             3        1613  0.233378  2138.346202              0.001
# 14             4        1993  0.227582  2119.490762              0.001
#
#     irstp_damage  Utility 2105  Disutility 2105  Temperature overshoot 2105
# 0       0.003592   9900.162398        44.999984                         7.0
# 1       0.001011   9993.835324        46.999938                         7.0
# 2       0.002942   9957.167468        45.999968                         7.0
# 3       0.001136  10086.708814        20.999961                         5.0
# 4       0.001439  10118.147351        21.999878                         5.0
# 5       0.003342  10032.850291        19.999992                         5.0
# 6       0.007865  10070.397044        21.999995                         6.0
# 7       0.005203  10112.217083        23.998729                         6.0
# 8       0.004191   9954.719740        19.999982                         6.0
# 9       0.011909  10100.599138        22.999960                         6.0
# 10      0.006129  10029.439721        17.999970                         6.0
# 11      0.005698  10034.466658        18.569247                         6.0
# 12      0.003822   9863.343963        14.999944                         6.0
# 13      0.002887  10049.080310        32.738850                         7.0
# 14      0.007802  10040.457640        29.997403                         7.0

# %%
pf = ProblemFormulation.SUFFICIENTARIAN_DISAGGREGATED
df_SD = pd.read_csv(os.path.join(directory, f'sorted_{pf.name}.csv'))
df_SD
# Out:
#     Unnamed: 0.1  Unnamed: 0        sr          miu  irstp_consumption  \
# 0              0         599  0.190942  2065.000000              0.001
# 1              1         710  0.128922  2065.000000              0.001
# 2              0         248  0.170948  2065.000000              0.001
# 3              1         391  0.179226  2065.000003              0.001
# 4              2         726  0.239451  2065.000000              0.001
# 5              0         577  0.104831  2065.000000              0.001
# 6              1         623  0.110886  2065.000000              0.001
# 7              2         753  0.128515  2065.000000              0.001
# 8              0          62  0.235993  2138.959771              0.001
# 9              1         363  0.177417  2065.000000              0.001
# 10             2         522  0.229926  2132.362055              0.001
# 11             3        1283  0.236495  2154.511000              0.001
# 12             4        1936  0.137970  2065.000000              0.001
# 13             5        2139  0.245663  2065.000000              0.001
#
#     irstp_damage  Utility 2105  Disutility 2105  \
# 0       0.001569   9985.107546        46.699927
# 1       0.008855   9900.162976        44.999993
# 2       0.001550  10086.708953        20.999964
# 3       0.012257  10095.328544        21.213890
# 4       0.002770  10126.458234        22.677801
# 5       0.001513   9954.719874        19.999984
# 6       0.007124   9969.689514        20.200521
# 7       0.008880  10007.940995        20.768113
# 8       0.012356  10049.587381        32.926626
# 9       0.013760   9999.643511        16.993819
# 10      0.013964  10046.448646        31.946043
# 11      0.009184  10052.817729        34.338508
# 12      0.002944   9944.578742        15.999986
# 13      0.001223  10034.440001        18.550027
#
#     Distance to consumption threshold 2105  \
# 0                                 0.000000
# 1                                 0.000000
# 2                                 0.000000
# 3                                 0.000000
# 4                                 0.000000
# 5                                 0.000000
# 6                                 0.000000
# 7                                 0.000000
# 8                                 0.498544
# 9                                 0.113588
# 10                                0.470450
# 11                                0.540033
# 12                                0.091394
# 13                                0.151059
#
#     Population below consumption threshold 2105  \
# 0                                      0.000000
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.000000
# 5                                      0.000000
# 6                                      0.000000
# 7                                      0.000000
# 8                                    372.619894
# 9                                    372.619894
# 10                                   372.619894
# 11                                   372.619894
# 12                                   372.619894
# 13                                   372.619894
#
#     Distance to damage threshold 2105  Population above damage threshold 2105  \
# 0                            0.899187                             4536.524725
# 1                            0.763629                             4536.524725
# 2                            0.383910                             1863.099468
# 3                            0.399280                             1863.099468
# 4                            0.515427                             3056.983403
# 5                            0.451491                             1863.099468
# 6                            0.463791                             1863.099468
# 7                            0.499997                             3056.983403
# 8                            1.871365                             6033.628846
# 9                            0.499997                             3056.983403
# 10                           1.787641                             6033.628846
# 11                           1.993189                             6033.628846
# 12                           0.433208                             3056.983403
# 13                           0.621195                             3056.983403
#
#     Temperature overshoot 2105
# 0                          7.0
# 1                          7.0
# 2                          5.0
# 3                          5.0
# 4                          5.0
# 5                          6.0
# 6                          6.0
# 7                          6.0
# 8                          7.0
# 9                          6.0
# 10                         7.0
# 11                         7.0
# 12                         6.0
# 13                         6.0

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

sns.set(style = "darkgrid")
sns.set(rc={'figure.figsize': (12, 8)})

fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

x, y, z = (df_UD[name] for name in outcome_names)

ax.set_xlabel(outcome_names[0])
ax.set_ylabel(outcome_names[1])
ax.set_zlabel(outcome_names[2])

ax.scatter(x, y, z)

plt.show()
# Out:
# <div id='a7d3e86f-99e1-4ab1-bc33-d7d488af7d84'></div>
