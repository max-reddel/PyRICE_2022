# %% [markdown]
# # Convergence Behavior of directed policy search
#
# Directed policy search has been run for each problem formulation. The convergence behavior for `Epsilon-Porgress` and for `Hypervolume` are shown below.

# %%
import os
from dmdu.general.convergence import plot_epsilon_progress, plot_hypervolumes
from model.enumerations import ProblemFormulation

# %% [markdown]
# ## Parameters

# %%
data_folder_path = os.path.join(
    os.path.dirname(os.getcwd()),
    'data'
)

problem_formulations = [
    ProblemFormulation.UTILITARIAN_AGGREGATED,
    # ProblemFormulation.UTILITARIAN_DISAGGREGATED,
    # ProblemFormulation.SUFFICIENTARIAN_AGGREGATED,
    # ProblemFormulation.SUFFICIENTARIAN_DISAGGREGATED,
    ProblemFormulation.EGALITARIAN_AGGREGATED,
    # ProblemFormulation.EGALITARIAN_DISAGGREGATED,
    # ProblemFormulation.PRIORITARIAN_AGGREGATED,
    # ProblemFormulation.PRIORITARIAN_DISAGGREGATED

]

searchover = 'levers'
nfe = 200000
n_references = 4
n_seeds = 2
saving = True

# %% [markdown]
# ## Visualization of $\epsilon$-Progress

# %%
plot_epsilon_progress(
    data_folder_path=data_folder_path,
    searchover=searchover,
    nfe=nfe,
    problem_formulations=problem_formulations,
    n_references=n_references,
    n_seeds=n_seeds,
    saving=saving,
    file_name='convergence_epsilon_proress_UE'
)

# %% [markdown]
# ## Visualization of Hypervolume

# %%
data_folder_path = os.path.join(
    os.path.dirname(os.getcwd()),
    'data'
)
plot_hypervolumes(
    data_folder_path=data_folder_path,
    searchover=searchover,
    nfe=nfe,
    problem_formulations=problem_formulations,
    n_seeds=n_seeds,
    n_references=n_references,
    saving=saving,
    file_name='convergence_hypervolume_UE'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#       1 data_folder_path = os.path.join(
#       2     os.path.dirname(os.getcwd()),
#       3     'data'
#       4 )
# ----> 5 plot_hypervolumes(
#       6     data_folder_path=data_folder_path,
#       7     searchover=searchover,
#       8     nfe=nfe,
#       9     problem_formulations=problem_formulations,
#      10     n_seeds=n_seeds,
#      11     n_references=n_references,
#      12     saving=saving,
#      13     file_name='convergence_hypervolume_UE'
#      14 )
#
# File ~/PycharmProjects/PyRICE_2022/dmdu/general/convergence.py:451, in plot_hypervolumes(data_folder_path, searchover, nfe, problem_formulations, n_seeds, n_references, saving, file_name)
#     449     file_name = 'hypervolume'
#     450 file_name += '.png'
# --> 451 fig.savefig(os.path.join(visualization_folder, file_name), dpi=200, pad_inches=0.2)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/figure.py:3046, in Figure.savefig(self, fname, transparent, **kwargs)
#    3042     for ax in self.axes:
#    3043         stack.enter_context(
#    3044             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3046 self.canvas.print_figure(fname, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:541, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     494 """
#     495 Write the figure to a PNG file.
#     496
#    (...)
#     538     *metadata*, including the default 'Software' key.
#     539 """
#     540 FigureCanvasAgg.draw(self)
# --> 541 mpl.image.imsave(
#     542     filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/image.py:1675, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673 pil_kwargs.setdefault("format", format)
#    1674 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675 image.save(fname, **pil_kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/PIL/Image.py:2297, in Image.save(self, fp, format, **params)
#    2295         fp = builtins.open(filename, "r+b")
#    2296     else:
# -> 2297         fp = builtins.open(filename, "w+b")
#    2299 try:
#    2300     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/reddel/PycharmProjects/PyRICE_2022/dmdu/policydiscovery/dmdu/outputimages/convergence_hypervolume_UE.png'
