# %% [markdown]
# # Convergence Behavior of directed policy search
#
# Directed policy search has been run for each problem formulation. The convergence behavior for `Epsilon-Porgress` and for `Hypervolume` are shown below.

# %%
import os
from dmdu.general.convergence import plot_epsilon_progress, plot_hypervolumes
from model.enumerations import ProblemFormulation

# %% [markdown]
# ## Parameters

# %%
data_folder_path = os.path.join(
    os.path.dirname(os.getcwd()),
    'data'
)

problem_formulations = [
    ProblemFormulation.UTILITARIAN_AGGREGATED,
    ProblemFormulation.UTILITARIAN_DISAGGREGATED,
    ProblemFormulation.SUFFICIENTARIAN_AGGREGATED,
    ProblemFormulation.SUFFICIENTARIAN_DISAGGREGATED,
    ProblemFormulation.EGALITARIAN_AGGREGATED,
    ProblemFormulation.EGALITARIAN_DISAGGREGATED,
    ProblemFormulation.PRIORITARIAN_AGGREGATED,
    ProblemFormulation.PRIORITARIAN_DISAGGREGATED

]

searchover = 'levers'
nfe = 200000
n_references = 4
n_seeds = 2
saving = True

# %% [markdown]
# ## Visualization of $\epsilon$-Progress

# %%
plot_epsilon_progress(
    data_folder_path=data_folder_path,
    searchover=searchover,
    nfe=nfe,
    problem_formulations=problem_formulations,
    n_references=n_references,
    n_seeds=n_seeds,
    saving=saving,
    file_name='convergence_epsilon_proress_all'
)

# %% [markdown]
# ## Visualization of Hypervolume

# %%
data_folder_path = os.path.join(
    os.path.dirname(os.getcwd()),
    'data'
)
plot_hypervolumes(
    data_folder_path=data_folder_path,
    searchover=searchover,
    nfe=nfe,
    problem_formulations=problem_formulations,
    n_seeds=n_seeds,
    n_references=n_references,
    saving=saving,
    file_name='convergence_hypervolume_all'
)
# Out:
# ---------------------------------------------------------------------------
# PlatypusError                             Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       1 data_folder_path = os.path.join(
#       2     os.path.dirname(os.getcwd()),
#       3     'data'
#       4 )
# ----> 5 plot_hypervolumes(
#       6     data_folder_path=data_folder_path,
#       7     searchover=searchover,
#       8     nfe=nfe,
#       9     problem_formulations=problem_formulations,
#      10     n_seeds=n_seeds,
#      11     n_references=n_references,
#      12     saving=saving,
#      13     file_name='convergence_hypervolume_all'
#      14 )
#
# File ~/PycharmProjects/PyRICE_2022/dmdu/general/convergence.py:420, in plot_hypervolumes(data_folder_path, searchover, nfe, problem_formulations, n_seeds, n_references, saving, file_name)
#     411 directory = os.path.join(
#     412     data_folder_path,
#     413     f'{problem_formulation.name}_{nfe}',
#    (...)
#     416     'hypervolume'
#     417 )
#     419 # Compute single hypervolume
# --> 420 values = _wrapper_hypervolume(directory, problem_formulation)
#     422 # Plotting
#     423 axes[pf_idx, reference_idx].plot(
#     424     *values,
#     425     color=color_mapping[seed_idx],
#     426     label=f'seed {seed_idx}'
#     427 )
#
# File ~/PycharmProjects/PyRICE_2022/dmdu/general/convergence.py:315, in _wrapper_hypervolume(hypervolume_path, problem_formulation)
#     312 ref_set = _create_a_reference_set(problem, n_decision_vars, n_objs, hypervolume_path, id)
#     313 archives = _load_and_merge_archives(problem, n_decision_vars, n_objs, hypervolume_path, id)
# --> 315 nfes, hvs = _compute_hypervolumes(ref_set, archives)
#     317 return nfes, hvs
#
# File ~/PycharmProjects/PyRICE_2022/dmdu/general/convergence.py:290, in _compute_hypervolumes(ref_set, archives_dict)
#     282 def _compute_hypervolumes(ref_set, archives_dict):
#     283     """
#     284     @param ref_set: list as reference set
#     285     @param archives_dict: dictionary: merged archives
#    (...)
#     288         hvs: float: list with hypervolumes
#     289     """
# --> 290     hv = Hypervolume(reference_set=ref_set)
#     291     nfes = []
#     292     hvs = []
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/platypus/indicators.py:114, in Hypervolume.__init__(self, reference_set, minimum, maximum)
#     112         raise ValueError("minimum and maximum must not be specified if reference_set is defined")
#     113     self.reference_set = [s for s in reference_set if s.constraint_violation==0.0]
# --> 114     self.minimum, self.maximum = normalize(reference_set)
#     115 else:
#     116     if minimum is None or maximum is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/platypus/core.py:1240, in normalize(solutions, minimum, maximum)
#    1237         maximum = [max([s.objectives[i] for s in feasible]) for i in range(problem.nobjs)]
#    1239 if any([maximum[i]-minimum[i] < EPSILON for i in range(problem.nobjs)]):
# -> 1240     raise PlatypusError("objective with empty range")
#    1242 for s in feasible:
#    1243     s.normalized_objectives = [(s.objectives[i] - minimum[i]) / (maximum[i] - minimum[i]) for i in range(problem.nobjs)]
#
# PlatypusError: objective with empty range
