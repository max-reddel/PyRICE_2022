# %%
import os


# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))

# Change the current working directory
os.chdir('/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022')

# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: /Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery
# Current working directory: /Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022

# %%
from dmdu.general.directed_search import run_optimization
from model.enumerations import *

import random
import numpy as np
import pandas as pd
from dmdu.scenariodiscovery.selection.scenario_selection import load_reference_scenarios
from dmdu.general.xlm_constants_epsilons import get_lever_names
from ema_workbench import Policy

# %%
# class PolicyCounter(object):
#     """
#     A helper object
#     """

#     def __init__(self):
#         self.counter = 0

#     def next(self):
#         """
#         Increment and return next policy id.
#         @return:
#             next_id: int
#         """
#         next_id = self.counter
#         self.counter += 1
#         return next_id


# def load_optimal_policies(
#         target_directory,
#         problem_formulations=None,
#         searchover='levers',
#         nfe=200000,
#         n_references=4,
#         n_seeds=1,
# ):
#     """
#     Loads Pareto-optimal policies
#     @param target_directory: String
#     @param problem_formulations: list with ProblemFormulation objects
#     @param searchover: String: {'uncertainties', 'levers'}
#     @param nfe: int
#     @param n_references: int: number of used reference scenarios
#     @param n_seeds: int: how many seeds have been used
#     @return:
#         optimal_policies: dictionary with {ProblemFormulation: list with Policy objects}

#     """
#     if problem_formulations is None:
#         problem_formulations = ProblemFormulation.get_util_and_suff_problem_formulations()

#     optimal_policies = {}
#     policies = None
#     counter = PolicyCounter()

#     reference_name = 'reference_scenario' if searchover == 'levers' else 'reference_policy'

#     for problem_formulation in problem_formulations:
#         for seed_index in range(n_seeds):
#             for n_reference in range(n_references):

#                 problem_folder = f'{problem_formulation.name}_{nfe}'
#                 seed_folder = f'seed_{seed_index}'
#                 reference_folder = f'{reference_name}_{n_reference}'

#                 current_directory = os.path.join(
#                     target_directory, problem_folder, seed_folder, reference_folder, 'results.csv'
#                 )

#                 df = pd.read_csv(current_directory, index_col='Unnamed: 0')
#                 if policies is None:
#                     policies = df
#                 else:
#                     policies = pd.concat([policies, df])

#         # Keep only lever columns
#         lever_names = get_lever_names()
#         policies = policies.loc[:, lever_names]

#         policies = [Policy(f'{counter.next()}', **row) for _, row in policies.iterrows()]

#         optimal_policies[problem_formulation] = policies
#         policies = None

#     return optimal_policies


# def load_optimal_policy_dataframes(
#         target_directory,
#         problem_formulations,
#         searchover='levers',
#         nfe=200000,
#         n_references=4,
#         n_seeds=1,
# ):
#     """
#     Loads dataframe from Pareto-optimal policies
#     @param target_directory: String
#     @param problem_formulations: list with ProblemFormulation objects
#     @param searchover: String: {'uncertainties', 'levers'}
#     @param nfe: int
#     @param n_references: int: number of used reference scenarios
#     @param n_seeds: int: how many seeds have been used
#     @return:
#         optimal_policies: dictionary with {ProblemFormulation: DataFrame}

#     """

#     optimal_policies = {}
#     reference_name = 'reference_scenario' if searchover == 'levers' else 'reference_policy'

#     for problem_formulation in problem_formulations:
#         policies = None
#         for seed_index in range(n_seeds):
#             for n_reference in range(n_references):

#                 if (seed_index == 1) and ((n_reference == 2) or (n_reference == 3)) and (problem_formulation == ProblemFormulation.EGALITARIAN_DISAGGREGATED):
#                     continue
#                 else:
#                     problem_folder = f'{problem_formulation.name}_{nfe}'
#                     seed_folder = f'seed_{seed_index}'
#                     reference_folder = f'{reference_name}_{n_reference}'

#                     current_directory = os.path.join(
#                         target_directory,
#                         problem_folder,
#                         seed_folder,
#                         reference_folder,
#                         'results.csv'
#                     )

#                     df = pd.read_csv(current_directory, index_col='Unnamed: 0')
#                     df = df.loc[:, get_lever_names()]

#                     if policies is None:
#                         policies = df
#                     else:
#                         policies = pd.concat([policies, df])
#                         policies.index = list(range(len(policies)))

#         optimal_policies[problem_formulation] = policies

#     return optimal_policies

# %%
seeds = [9845531, 1644652]
problem_formulations = [
    # ProblemFormulation.EGALITARIAN_AGGREGATED,
    ProblemFormulation.EGALITARIAN_DISAGGREGATED,
    ProblemFormulation.PRIORITARIAN_AGGREGATED,
    #ProblemFormulation.PRIORITARIAN_DISAGGREGATED
]
reference_scenarios = load_reference_scenarios()

for problem_formulation in problem_formulations:
    for seed_index, seed in enumerate(seeds):
        for reference_index, reference_scenario in enumerate(reference_scenarios):

            # Setting seeds
            random.seed(seed)
            np.random.seed(seed)

            # Run optimizations
            run_optimization(
                problem_formulation=problem_formulation,
                nfe=2000,  #200000
                searchover='levers',
                seed_index=seed_index,
                reference=(reference_index, reference_scenario),
                saving_results=True,
                with_convergence=True
            )
# Out:
#  10%|███▉                                   | 200/2000 [00:07<01:02, 28.72it/s]Process SpawnPoolWorker-199:
# Process SpawnPoolWorker-195:
# Process SpawnPoolWorker-192:
# Process SpawnPoolWorker-193:
# Process SpawnPoolWorker-198:
# Process SpawnPoolWorker-197:
# Process SpawnPoolWorker-194:
# Process SpawnPoolWorker-196:
# Process SpawnPoolWorker-191:
# Traceback (most recent call last):
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/ema_multiprocessing.py", line 168, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/util/ema_logging.py", line 152, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/util/ema_logging.py", line 152, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/model.py", line 350, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/util/ema_logging.py", line 152, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/model.py", line 403, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/model/pyrice.py", line 294, in __call__
#     self.temp_atm = self.climate_model.run(
#   File "/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/model/submodels/climate_model.py", line 209, in run
#     self.GSICREMAIN[t] = self.gsictotal - self.GSICCUM[t - 1]
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb Cell 4' in <cell line: 10>()
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=15'>16</a> np.random.seed(seed)
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=17'>18</a> # Run optimizations
# ---> <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=18'>19</a> run_optimization(
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=19'>20</a>     problem_formulation=problem_formulation,
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=20'>21</a>     nfe=2000,  #200000
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=21'>22</a>     searchover='levers',
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=22'>23</a>     seed_index=seed_index,
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=23'>24</a>     reference=(reference_index, reference_scenario),
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=24'>25</a>     saving_results=True,
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=25'>26</a>     with_convergence=True
#      <a href='vscode-notebook-cell:/Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/policydiscovery/directed_policy_search_adaptive.ipynb#ch0000003?line=26'>27</a> )
#
# File ~/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py:148, in run_optimization(damage_function, problem_formulation, nfe, searchover, seed_index, reference, saving_results, with_convergence)
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=137'>138</a> convergence_metrics = [
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=138'>139</a>     EpsilonProgress(),
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=139'>140</a>     ArchiveLogger(
#    (...)
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=143'>144</a>     ),
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=144'>145</a> ]
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=146'>147</a> with MultiprocessingEvaluator(model) as evaluator:
# --> <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=147'>148</a>     results, convergence = evaluator.optimize(
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=148'>149</a>         nfe=nfe,
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=149'>150</a>         searchover=searchover,
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=150'>151</a>         epsilons=epsilons,
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=151'>152</a>         convergence=convergence_metrics,
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=152'>153</a>         reference=reference
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=153'>154</a>     )
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=155'>156</a>     if saving_results:
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=156'>157</a>         # Save results_formatted
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=157'>158</a>         path = define_path_name(
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=158'>159</a>             problem_formulation=problem_formulation,
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=159'>160</a>             nfe=nfe,
#    (...)
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=163'>164</a>             searchover=searchover,
#     <a href='file:///Users/palokbiswas/Library/CloudStorage/OneDrive-Personal/AI_NL_PhD_2022/CURRENT_22-23-RICE/PyRICE_Max_New/PyRICE_2022/dmdu/general/directed_search.py?line=164'>165</a>         )
#
# File ~/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py:234, in BaseEvaluator.optimize(self, algorithm, nfe, searchover, reference, constraints, convergence_freq, logging_freq, **kwargs)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=216'>217</a> def optimize(
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=217'>218</a>     self,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=218'>219</a>     algorithm=EpsNSGAII,
#    (...)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=225'>226</a>     **kwargs,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=226'>227</a> ):
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=227'>228</a>     """convenience method for outcome optimization.
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=228'>229</a>
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=229'>230</a>     is forwarded to :func:optimize, with evaluator and models
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=230'>231</a>     arguments added in.
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=231'>232</a>
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=232'>233</a>     """
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=233'>234</a>     return optimize(
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=234'>235</a>         self._msis,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=235'>236</a>         algorithm=algorithm,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=236'>237</a>         nfe=int(nfe),
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=237'>238</a>         searchover=searchover,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=238'>239</a>         evaluator=self,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=239'>240</a>         reference=reference,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=240'>241</a>         constraints=constraints,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=241'>242</a>         convergence_freq=convergence_freq,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=242'>243</a>         logging_freq=logging_freq,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=243'>244</a>         **kwargs,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=244'>245</a>     )
#
# File ~/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py:716, in optimize(models, algorithm, nfe, searchover, evaluator, reference, convergence, constraints, convergence_freq, logging_freq, **kwargs)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=712'>713</a> if not evaluator:
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=713'>714</a>     evaluator = SequentialEvaluator(models)
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=715'>716</a> return _optimize(
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=716'>717</a>     problem,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=717'>718</a>     evaluator,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=718'>719</a>     algorithm,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=719'>720</a>     convergence,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=720'>721</a>     nfe,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=721'>722</a>     convergence_freq,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=722'>723</a>     logging_freq,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=723'>724</a>     **kwargs,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=724'>725</a> )
#
# File ~/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/optimization.py:865, in _optimize(problem, evaluator, algorithm, convergence, nfe, convergence_freq, logging_freq, **kwargs)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/optimization.py?line=861'>862</a> evaluator.callback = callback
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/optimization.py?line=863'>864</a> with temporary_filter(name=[callbacks.__name__, evaluators.__name__], level=INFO):
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/optimization.py?line=864'>865</a>     optimizer.run(nfe)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/optimization.py?line=866'>867</a> convergence(optimizer)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/optimization.py?line=868'>869</a> # convergence.pbar.__exit__(None, None, None)
#
# File ~/miniforge3/lib/python3.9/site-packages/platypus/core.py:408, in Algorithm.run(self, condition, callback)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=404'>405</a> LOGGER.log(logging.INFO, "%s starting", type(self).__name__)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=406'>407</a> while not condition(self):
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=407'>408</a>     self.step()
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=409'>410</a>     if self.log_frequency is not None and self.nfe >= last_log + self.log_frequency:
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=410'>411</a>         LOGGER.log(logging.INFO,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=411'>412</a>                    "%s running; NFE Complete: %d, Elapsed Time: %s",
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=412'>413</a>                    type(self).__name__,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=413'>414</a>                    self.nfe,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=414'>415</a>                    datetime.timedelta(seconds=time.time()-start_time))
#
# File ~/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py:1522, in PeriodicAction.step(self)
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=1520'>1521</a> def step(self):
# -> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=1521'>1522</a>     self.algorithm.step()
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=1522'>1523</a>     self.iteration += 1
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=1523'>1524</a>     self.nfe = self.algorithm.nfe
#
# File ~/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py:183, in NSGAII.step(self)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=180'>181</a>     self.initialize()
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=181'>182</a> else:
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=182'>183</a>     self.iterate()
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=184'>185</a> if self.archive is not None:
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=185'>186</a>     self.result = self.archive
#
# File ~/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py:206, in NSGAII.iterate(self)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=202'>203</a>     parents = self.selector.select(self.variator.arity, self.population)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=203'>204</a>     offspring.extend(self.variator.evolve(parents))
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=205'>206</a> self.evaluate_all(offspring)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=207'>208</a> offspring.extend(self.population)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/algorithms.py?line=208'>209</a> nondominated_sort(offspring)
#
# File ~/miniforge3/lib/python3.9/site-packages/platypus/core.py:381, in Algorithm.evaluate_all(self, solutions)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=377'>378</a> unevaluated = [s for s in solutions if not s.evaluated]
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=379'>380</a> jobs = [_EvaluateJob(s) for s in unevaluated]
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=380'>381</a> results = self.evaluator.evaluate_all(jobs)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=382'>383</a> # if needed, update the original solution with the results
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/platypus/core.py?line=383'>384</a> for i, result in enumerate(results):
#
# File ~/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py:162, in BaseEvaluator.evaluate_all(self, jobs, **kwargs)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=158'>159</a>     raise NotImplementedError()
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=160'>161</a> # overwrite the default 10 progress reports  with 5 reports
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=161'>162</a> callback = perform_experiments(
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=162'>163</a>     self._msis,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=163'>164</a>     evaluator=self,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=164'>165</a>     reporting_frequency=self.reporting_frequency,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=165'>166</a>     scenarios=scenarios,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=166'>167</a>     policies=policies,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=167'>168</a>     return_callback=True,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=168'>169</a>     log_progress=True,
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=169'>170</a> )
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=171'>172</a> experiments, outcomes = callback.get_results()
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=173'>174</a> if searchover in ("levers", "uncertainties"):
#
# File ~/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py:539, in perform_experiments(models, scenarios, policies, evaluator, reporting_interval, reporting_frequency, uncertainty_union, lever_union, outcome_union, uncertainty_sampling, lever_sampling, callback, return_callback, combine, log_progress)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=535'>536</a> if not evaluator:
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=536'>537</a>     evaluator = SequentialEvaluator(models)
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=538'>539</a> evaluator.evaluate_experiments(scenarios, policies, callback, combine=combine)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=540'>541</a> if callback.i != nr_of_exp:
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=541'>542</a>     raise EMAError(
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=542'>543</a>         (
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=543'>544</a>             "some fatal error has occurred while "
#    (...)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=546'>547</a>         ).format(nr_of_exp, callback.i)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=547'>548</a>     )
#
# File ~/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py:380, in MultiprocessingEvaluator.evaluate_experiments(self, scenarios, policies, callback, combine)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=377'>378</a> def evaluate_experiments(self, scenarios, policies, callback, combine="factorial"):
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=378'>379</a>     ex_gen = experiment_generator(scenarios, self._msis, policies, combine=combine)
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py?line=379'>380</a>     add_tasks(self.n_processes, self._pool, ex_gen, callback)
#
# File ~/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/ema_multiprocessing.py:284, in add_tasks(n_processes, pool, experiments, callback)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/ema_multiprocessing.py?line=280'>281</a> feeder.start()
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/ema_multiprocessing.py?line=281'>282</a> reader.start()
# --> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/ema_multiprocessing.py?line=283'>284</a> feeder.join()
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/ema_multiprocessing.py?line=284'>285</a> results_queue.put(None)
#     <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/site-packages/ema_workbench/em_framework/ema_multiprocessing.py?line=285'>286</a> reader.join()
#
# File ~/miniforge3/lib/python3.9/threading.py:1053, in Thread.join(self, timeout)
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1049'>1050</a>     raise RuntimeError("cannot join current thread")
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1051'>1052</a> if timeout is None:
# -> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1052'>1053</a>     self._wait_for_tstate_lock()
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1053'>1054</a> else:
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1054'>1055</a>     # the behavior of a negative timeout isn't documented, but
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1055'>1056</a>     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1056'>1057</a>     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/miniforge3/lib/python3.9/threading.py:1073, in Thread._wait_for_tstate_lock(self, block, timeout)
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1069'>1070</a>     return
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1071'>1072</a> try:
# -> <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1072'>1073</a>     if lock.acquire(block, timeout):
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1073'>1074</a>         lock.release()
#    <a href='file:///Users/palokbiswas/miniforge3/lib/python3.9/threading.py?line=1074'>1075</a>         self._stop()
#
# KeyboardInterrupt:
#  10%|███▉                                   | 200/2000 [00:26<01:02, 28.72it/s]
