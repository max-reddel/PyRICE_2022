# %% [markdown]
# # Convergence Behavior of directed policy search
#
# Directed policy search has been run for each problem formulation. The convergence behavior for `Epsilon-Porgress` and for `Hypervolume` are shown below.

# %%
import os
from dmdu.general.convergence import plot_epsilon_progress, plot_hypervolumes
from model.enumerations import ProblemFormulation

# %% [markdown]
# ## Parameters

# %%
data_folder_path = os.path.join(os.getcwd(), 'data')

problem_formulations = [
    # ProblemFormulation.EGALITARIAN_AGGREGATED,
    # ProblemFormulation.EGALITARIAN_DISAGGREGATED,
    ProblemFormulation.UTILITARIAN_AGGREGATED,
    ProblemFormulation.UTILITARIAN_DISAGGREGATED,
    ProblemFormulation.SUFFICIENTARIAN_AGGREGATED,
    ProblemFormulation.SUFFICIENTARIAN_DISAGGREGATED,

]

searchover = 'levers'
nfe = 200000
n_references = 4
n_seeds = 1
saving = True

# %% [markdown]
# ## Visualization of $\epsilon$-Progress

# %%
plot_epsilon_progress(
    data_folder_path=data_folder_path,
    searchover=searchover,
    nfe=nfe,
    problem_formulations=problem_formulations,
    n_references=n_references,
    n_seeds=n_seeds,
    saving=saving,
    file_name='convergence_epsilon_proress'
)

# %% [markdown]
# ## Visualizatoin of Hypervolume

# %%
data_folder_path = os.path.join(os.getcwd(), 'data')
plot_hypervolumes(
    data_folder_path=data_folder_path,
    searchover=searchover,
    nfe=nfe,
    problem_formulations=problem_formulations,
    n_seeds=n_seeds,
    n_references=n_references,
    saving=saving,
    file_name='convergence_hypervolume'
)
# Out:
# ---------------------------------------------------------------------------
# PlatypusError                             Traceback (most recent call last)
# <ipython-input-4-0891e76f88f1> in <module>
#       1 data_folder_path = os.path.join(os.getcwd(), 'data')
# ----> 2 plot_hypervolumes(
#       3     data_folder_path=data_folder_path,
#       4     searchover=searchover,
#       5     nfe=nfe,
#
# ~/PycharmProjects/PyRICE_2022/dmdu/general/convergence.py in plot_hypervolumes(data_folder_path, searchover, nfe, problem_formulations, n_seeds, n_references, saving, file_name)
#     410
#     411                 # Compute single hypervolume
# --> 412                 values = _wrapper_hypervolume(directory, problem_formulation)
#     413
#     414                 # Plotting
#
# ~/PycharmProjects/PyRICE_2022/dmdu/general/convergence.py in _wrapper_hypervolume(hypervolume_path, problem_formulation)
#     305     archives = _load_and_merge_archives(problem, n_decision_vars, n_objs, hypervolume_path, id)
#     306
# --> 307     nfes, hvs = _compute_hypervolumes(ref_set, archives)
#     308
#     309     return nfes, hvs
#
# ~/PycharmProjects/PyRICE_2022/dmdu/general/convergence.py in _compute_hypervolumes(ref_set, archives_dict)
#     280         hvs: float: list with hypervolumes
#     281     """
# --> 282     hv = Hypervolume(reference_set=ref_set)
#     283     nfes = []
#     284     hvs = []
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/platypus/indicators.py in __init__(self, reference_set, minimum, maximum)
#     112                 raise ValueError("minimum and maximum must not be specified if reference_set is defined")
#     113             self.reference_set = [s for s in reference_set if s.constraint_violation==0.0]
# --> 114             self.minimum, self.maximum = normalize(reference_set)
#     115         else:
#     116             if minimum is None or maximum is None:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/platypus/core.py in normalize(solutions, minimum, maximum)
#    1238
#    1239     if any([maximum[i]-minimum[i] < EPSILON for i in range(problem.nobjs)]):
# -> 1240         raise PlatypusError("objective with empty range")
#    1241
#    1242     for s in feasible:
#
# PlatypusError: objective with empty range
