# %% [markdown]
# # Visualization of Convergence
#
# For this purpose, the 4 problem formulations from the directory `problemformulations` have been run. Each problem formulation used 100,000 nfe. The results and $\epsilon$-progress have been saved in the directory `results`.

# %% [markdown]
# ## Imports

# %%
from optimization.visualizations.epsilon_progress import *
from optimization.visualizations.hypervolume import *

# %% [markdown]
# ## Visualize $\epsilon$-Progress

# %%
visualize_epsilon_progress(saving=True)

# %% [markdown]
# ## Visualize Hypervolume

# %%
hypervolume_dict = {
    'Nordhaus + Utilitarian': wrapper_hypervolume(problem_formulation='NORDHAUS/UTILITARIAN', id=196),
    'Weitzman + Utilitarian': wrapper_hypervolume(problem_formulation='WEITZMAN/UTILITARIAN', id=195),
    'Nordhaus + Sufficientarian': wrapper_hypervolume(problem_formulation='NORDHAUS/SUFFICIENTARIAN', id=199),
    'Weitzman + Sufficientarian': wrapper_hypervolume(problem_formulation='WEITZMAN/SUFFICIENTARIAN', id=198)}

plot_hypervolumes(hypervolume_dict, saving=True)
